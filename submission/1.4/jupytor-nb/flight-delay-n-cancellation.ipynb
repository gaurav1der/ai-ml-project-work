# %%
import pandas as pd
flight_status = pd.read_csv('/Users/gauravgoel/Documents/workspace/berkeley/python/datasets_starter/archive/flights_sample_3m_small.csv')

# %%
flight_status

df = pd.DataFrame(flight_status)
df
# Out:
#         FL_DATE                 AIRLINE                 AIRLINE_DOT  \
# 0    2019-01-09   United Air Lines Inc.   United Air Lines Inc.: UA
# 1    2022-11-19    Delta Air Lines Inc.    Delta Air Lines Inc.: DL
# 2    2022-07-22   United Air Lines Inc.   United Air Lines Inc.: UA
# 3    2023-03-06    Delta Air Lines Inc.    Delta Air Lines Inc.: DL
# 4    2020-02-23        Spirit Air Lines        Spirit Air Lines: NK
# ..          ...                     ...                         ...
# 494  2020-03-21   SkyWest Airlines Inc.   SkyWest Airlines Inc.: OO
# 495  2019-01-14        Spirit Air Lines        Spirit Air Lines: NK
# 496  2019-06-05    Delta Air Lines Inc.    Delta Air Lines Inc.: DL
# 497  2023-05-27  American Airlines Inc.  American Airlines Inc.: AA
# 498  2021-05-11  Southwest Airlines Co.  Southwest Airlines Co.: WN
#
#     AIRLINE_CODE  DOT_CODE  FL_NUMBER ORIGIN          ORIGIN_CITY DEST  \
# 0             UA     19977       1562    FLL  Fort Lauderdale, FL  EWR
# ...

# %%
# Describe numeric columns (default behavior)
print("Descriptive statistics for numeric columns:")
print(df.describe())

# Describe all columns, including categorical
print("\nDescriptive statistics for all columns:")
print(df.describe(include='all'))
# Out:
# Descriptive statistics for numeric columns:
#            DOT_CODE    FL_NUMBER  CRS_DEP_TIME     DEP_TIME    DEP_DELAY  \
# count    499.000000   499.000000    499.000000   488.000000   488.000000
# mean   19960.146293  2399.172345   1320.376754  1321.018443     8.713115
# std      375.823707  1714.677327    492.216349   502.452778    56.646565
# min    19393.000000     1.000000     59.000000    29.000000   -21.000000
# 25%    19790.000000   980.500000    853.500000   889.000000    -5.000000
# 50%    19930.000000  2027.000000   1320.000000  1316.500000    -3.000000
# 75%    20363.000000  3619.500000   1726.000000  1740.250000     6.000000
# max    20452.000000  6524.000000   2359.000000  2357.000000  1069.000000
#
#          TAXI_OUT   WHEELS_OFF    WHEELS_ON     TAXI_IN  CRS_ARR_TIME  ...  \
# count  488.000000   488.000000   488.000000  488.000000    499.000000  ...
# mean    16.401639  1344.551230  1462.387295    7.750000   1484.739479  ...
# ...
